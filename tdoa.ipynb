# %% [markdown]
# # Picture of setup
#
# ![](setup.jpg)

# %%
# %matplotlib inline

from __future__ import division

import matplotlib.pyplot as plt
from numpy import argmax, abs, correlate, floor, arange
from scipy.signal import correlate
from jacked import easy_client

# %%
START = 23000

# %%
with easy_client(name="captest", channels_in=2, channels_out=2) as client:
    captured = client.capture(sec=1)
    SAMPLE_RATE = client.sample_rate

# %%
captured
# Out:
# array([[  5.05447460e-05,   4.51803244e-05,   4.72068859e-05, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00],
#        [  3.45706985e-06,   5.96046539e-06,  -4.76837215e-07, ...,
#           0.00000000e+00,   0.00000000e+00,   0.00000000e+00]], dtype=float32)

# %%
plt.plot(captured[0])
plt.plot(captured[1])
plt.show()

# %%
plt.plot(captured[0, START:START+1000])
plt.plot(captured[1, START:START+1000])
plt.show()

# %% [markdown]
# # Attempt at TDOA
# ## Steps
#
# 1. cross correlate
# 2. find midpoint
# 3. compute argmax
# 4. argmax - midpoint is the time delay

# %%
def tdoa(end):
    correlated = correlate(captured[0,START:end], captured[1,START:end], mode='full')
    center = len(correlated)/2
    max_index = argmax(correlated)
    offset = max_index - center
    
    print("center: {}".format(center))
    print("sample offset {}".format(offset))
    print("tdoa: {} sec".format(offset/SAMPLE_RATE))
    
    plt.plot(arange(-center, center), correlated)
    plt.vlines(offset, 0, correlated[max_index])
    plt.axhline(0)
    plt.show()

# %%
tdoa(START+10)
# Out:
# center: 9.5
# sample offset 6.5
# tdoa: 0.000135416666667 sec

# %%
tdoa(START+100)
# Out:
# center: 99.5
# sample offset 1.5
# tdoa: 3.125e-05 sec

# %%
tdoa(START+500)
# Out:
# center: 499.5
# sample offset 56.5
# tdoa: 0.00117708333333 sec

# %%
tdoa(START+2000)
# Out:
# center: 1999.5
# sample offset 58.5
# tdoa: 0.00121875 sec
